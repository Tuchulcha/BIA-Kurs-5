# %% [markdown]
# ##Övning 4 Visualisera data över tid
# Visa att försäljningen är högre under andra än första halvåret

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
days_in_month = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]

# %%
sales_data = []

# %%
for month, days in enumerate(days_in_month):
    if month < 6:
        sales = np.random.randint(50, 100, days).tolist()
    else:
        sales = np.random.randint(100, 150, days).tolist()
    
    sales_data.extend(sales)

len(sales_data)
# Out:
# 365

# %%
df = pd.DataFrame({
    'Date': pd.date_range(start="2023-01-01", end="2023-12-31"),
    'Sales': sales_data})

# %%
# Set a style
sns.set(style="whitegrid")
# Create a figure and axes
plt.figure(figsize=(14, 6))
sns.lineplot(data=df, x="Date", y="Sales")
# Set title and labels
plt.title("Försäljning av produkter under 2023")
plt.xlabel("Datum")
plt.ylabel("Antal sålda produkter")
# Show the plot
plt.show()

# %%
# ...
# Calculate the 10-day average
df['10_Day_Avg'] = df['Sales'].rolling(window=10).mean()
sns.lineplot(data=df, x="Date", y="10_Day_Avg", label="10-dagars genomsnitt",
color='red')
# ...
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 38
#      35             productivity[i] -= np.random.randint(5, 11)  # Decrease by 5-10
#      37     # Update the DataFrame
# ---> 38     df.loc[working_hours, 'Coffee'] = coffee
#      39     df.loc[working_hours, 'Productivity'] = productivity
#      41 print(df)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:814, in _LocationIndexer.__setitem__(self, key, value)
#     812 else:
#     813     key = com.apply_if_callable(key, self.obj)
# --> 814 indexer = self._get_setitem_indexer(key)
#     815 self._has_valid_setitem_indexer(key)
#     817 iloc = self if self.name == "iloc" else self.obj.iloc
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:697, in _LocationIndexer._get_setitem_indexer(self, key)
#     694 if isinstance(key, tuple):
# ...
